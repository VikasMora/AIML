# %% [markdown]
# <a href="https://colab.research.google.com/github/VikasMora/AIML/blob/main/2303A52190_Asiignment_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
a = [1,2,3,6,9,5]
b = [4,5,7,8,11,5]
a =np.array(a)
b =np.array(b)
print(a+b)
# Out:
# [ 5  7 10 14 20 10]

# %%
print(np.min(a))
# Out:
# 1

# %%
print(np.max(a))
# Out:
# 9

# %%
print(np.sqrt(a))
# Out:
# [1.         1.41421356 1.73205081 2.44948974 3.         2.23606798]

# %%
print(np.tan(45))
# Out:
# 1.6197751905438615

# %%
print(np.mod(a,b))
# Out:
# [1 2 3 6 9 0]

# %%
m1 = [[1,2,3],[2,5,6,],[8,9,6]]
m2 = [[12,23,56],[21,25,66],[12,56,78]]
print(m1)
m1 = np.array(m1)
m2 = np.array(m2)
print(m1*m2)
# Out:
# [[1, 2, 3], [2, 5, 6], [8, 9, 6]]
# [[ 12  46 168]
#  [ 42 125 396]
#  [ 96 504 468]]

# %%
print(np.matmul(m1,m2))
# Out:
# [[  90  241  422]
#  [ 201  507  910]
#  [ 357  745 1510]]

# %%
print(np.trace(m1))
print(np.linalg.matrix_rank(m1))
# Out:
# 12
# 3

# %%
print(np.transpose(m1))
# Out:
# [[1 2 8]
#  [2 5 9]
#  [3 6 6]]

# %%
print(np.linalg.det(m1))
print(np.linalg.det(m2))
# Out:
# -17.999999999999996
# 8645.999999999995

# %%
print(np.linalg.inv(m1))
# Out:
# [[ 1.33333333e+00 -8.33333333e-01  1.66666667e-01]
#  [-2.00000000e+00  1.00000000e+00 -3.02788098e-17]
#  [ 1.22222222e+00 -3.88888889e-01 -5.55555556e-02]]

# %%
print(np.transpose(m1))
# Out:
# [[1 2 8]
#  [2 5 9]
#  [3 6 6]]

# %%
print(np.linalg.inv(m1))
# Out:
# [[ 1.33333333e+00 -8.33333333e-01  1.66666667e-01]
#  [-2.00000000e+00  1.00000000e+00 -3.02788098e-17]
#  [ 1.22222222e+00 -3.88888889e-01 -5.55555556e-02]]

# %%
print(np.linalg.eigvals(m1))
# Out:
# [14.7049366   0.39488662 -3.09982323]

# %%
import matplotlib.pyplot as plt
x = [1,36,56,85,32,15,46,59,78,35]
y = [125,23,98,56,45,78,99,46,66,45]
print(plt.plot(x,y))

# %%
print(plt.scatter(x,y))

# %%
plt.title("Numbers")
# Out:
# Text(0.5, 1.0, 'Numbers')

# %%
plt.hist(x,5)
# Out:
# (array([2., 1., 3., 2., 2.]),
#  array([ 1. , 17.8, 34.6, 51.4, 68.2, 85. ]),
#  <BarContainer object of 5 artists>)

# %%
plt.pie(x)
# Out:
# ([<matplotlib.patches.Wedge at 0x78f4bb78d510>,
# ...
#  [Text(1.0999723399358525, 0.007800729199588693, ''),
#   Text(1.0602998305897084, 0.29285537258420935, ''),
#   Text(0.6647275694058449, 0.8764344005524874, ''),
#   Text(-0.37825769817958, 1.0329187353165235, ''),
#   Text(-1.017383389756935, 0.4182475800846772, ''),
#   Text(-1.098230229263618, 0.062372778770723336, ''),
#   Text(-1.0232128978732329, -0.4037763807181661, ''),
#   Text(-0.47877751815820746, -0.9903393802663143, ''),
#   Text(0.5477466662851093, -0.9539253584917162, ''),
#   Text(1.0662899085536048, -0.2702329197502502, '')])

# %%
plt.pie(y)
# Out:
# ([<matplotlib.patches.Wedge at 0x78f4bba02470>,
# ...
#  [Text(0.9221228480254654, 0.5997411551239458, ''),
#   Text(0.3370217407977482, 1.04709901452998, ''),
#   Text(-0.2687392774557547, 1.0666673336858867, ''),
#   Text(-0.8993661252136872, 0.633356592148624, ''),
#   Text(-1.088035921633744, 0.16179565270615123, ''),
#   Text(-1.0044867651202847, -0.448337304602446, ''),
#   Text(-0.36108229089753385, -1.039047438378147, ''),
#   Text(0.3610823395388537, -1.0390474214746641, ''),
#   Text(0.8272328919301069, -0.7250418901752865, ''),
#   Text(1.076382559872839, -0.2267169706960523, '')])

# %%
plt.bar(x,y)
# Out:
# <BarContainer object of 10 artists>

# %%
import pandas as pd
a1 = pd.read_csv('/content/sample_data/california_housing_train.csv')
print(a1)
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -114.31     34.19                15.0       5612.0          1283.0
# 1        -114.47     34.40                19.0       7650.0          1901.0
# 2        -114.56     33.69                17.0        720.0           174.0
# 3        -114.57     33.64                14.0       1501.0           337.0
# 4        -114.57     33.57                20.0       1454.0           326.0
# ...          ...       ...                 ...          ...             ...
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
# ...

# %%
col1 = a1['longitude']
col2 = a1['latitude']
plt.plot(col1,col2)
